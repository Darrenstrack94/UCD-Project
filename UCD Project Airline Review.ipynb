# %%
import pandas as pd

# %%
df=pd.read_csv("data.csv")

# %%
df
# Out:
#           Airline_Name  Food_&_Beverages  Inflight_Entertainment  \
# 0          AB Aviation                 2                       0
# 1        Adria Airways                 3                       2
# 2      Aegean Airlines                 4                       2
# 3           Aer Lingus                 3                       2
# 4             Aero VIP                 0                       0
# ..                 ...               ...                     ...
# 510  XL Airways France                 3                       2
# 511   Yakutia Airlines                 3                       0
# 512     Yangon Airways                 4                       0
# 513            Yemenia                 0                       0
# 514      Yeti Airlines                 3                       0
#
#      Seat_Comfort  Staff_Service  Value_for_Money  Review_Count  Rating
# 0               3              3                2             3       4
# ...

# %%
Cleaning Missing Values (Delete) = df_cleaned=df.dropna()

# %%
df_cleaned
# Out:
#           Airline_Name  Food_&_Beverages  Inflight_Entertainment  \
# 0          AB Aviation                 2                       0
# 1        Adria Airways                 3                       2
# 2      Aegean Airlines                 4                       2
# 3           Aer Lingus                 3                       2
# 4             Aero VIP                 0                       0
# ..                 ...               ...                     ...
# 510  XL Airways France                 3                       2
# 511   Yakutia Airlines                 3                       0
# 512     Yangon Airways                 4                       0
# 513            Yemenia                 0                       0
# 514      Yeti Airlines                 3                       0
#
#      Seat_Comfort  Staff_Service  Value_for_Money  Review_Count  Rating
# 0               3              3                2             3       4
# ...

# %%
Cleaning Missing Columns (Delete) = df_cleaned=df.dropna(axis=1)

# %%
df_cleaned
# Out:
#           Airline_Name  Food_&_Beverages  Inflight_Entertainment  \
# 0          AB Aviation                 2                       0
# 1        Adria Airways                 3                       2
# 2      Aegean Airlines                 4                       2
# 3           Aer Lingus                 3                       2
# 4             Aero VIP                 0                       0
# ..                 ...               ...                     ...
# 510  XL Airways France                 3                       2
# 511   Yakutia Airlines                 3                       0
# 512     Yangon Airways                 4                       0
# 513            Yemenia                 0                       0
# 514      Yeti Airlines                 3                       0
#
#      Seat_Comfort  Staff_Service  Value_for_Money  Review_Count  Rating
# 0               3              3                2             3       4
# ...

# %%
Cleaning Missing Values (Filling With Average) = df_cleaned=df.fillna(df.mean())
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_8480/1283504667.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_cleaned=df.fillna(df.mean())

# %%
df_cleaned
# Out:
#           Airline_Name  Food_&_Beverages  Inflight_Entertainment  \
# 0          AB Aviation                 2                       0
# 1        Adria Airways                 3                       2
# 2      Aegean Airlines                 4                       2
# 3           Aer Lingus                 3                       2
# 4             Aero VIP                 0                       0
# ..                 ...               ...                     ...
# 510  XL Airways France                 3                       2
# 511   Yakutia Airlines                 3                       0
# 512     Yangon Airways                 4                       0
# 513            Yemenia                 0                       0
# 514      Yeti Airlines                 3                       0
#
#      Seat_Comfort  Staff_Service  Value_for_Money  Review_Count  Rating
# 0               3              3                2             3       4
# ...

# %%
Cleaning Missing Values (Filling With Backwards Fill)df.cleaned=df.fillna(method="bfill")
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_8480/691078564.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.cleaned=df.fillna(method="bfill")

# %%
df.cleaned
# Out:
#           Airline_Name  Food_&_Beverages  Inflight_Entertainment  \
# 0          AB Aviation                 2                       0
# 1        Adria Airways                 3                       2
# 2      Aegean Airlines                 4                       2
# 3           Aer Lingus                 3                       2
# 4             Aero VIP                 0                       0
# ..                 ...               ...                     ...
# 510  XL Airways France                 3                       2
# 511   Yakutia Airlines                 3                       0
# 512     Yangon Airways                 4                       0
# 513            Yemenia                 0                       0
# 514      Yeti Airlines                 3                       0
#
#      Seat_Comfort  Staff_Service  Value_for_Money  Review_Count  Rating
# 0               3              3                2             3       4
# ...

# %%
Drop Any Duplicates = df_cleaned=df.drop_duplicates()

# %%
df_cleaned
# Out:
#           Airline_Name  Food_&_Beverages  Inflight_Entertainment  \
# 0          AB Aviation                 2                       0
# 1        Adria Airways                 3                       2
# 2      Aegean Airlines                 4                       2
# 3           Aer Lingus                 3                       2
# 4             Aero VIP                 0                       0
# ..                 ...               ...                     ...
# 510  XL Airways France                 3                       2
# 511   Yakutia Airlines                 3                       0
# 512     Yangon Airways                 4                       0
# 513            Yemenia                 0                       0
# 514      Yeti Airlines                 3                       0
#
#      Seat_Comfort  Staff_Service  Value_for_Money  Review_Count  Rating
# 0               3              3                2             3       4
# ...

# %%
Number Of Row And Colums Have Stayed The Same The Whole Way Down. File Is Fully Cleaned
