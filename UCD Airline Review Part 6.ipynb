# %%
import pandas as pd

# %%
df=pd.read_csv("data.csv")

# %%
df
# Out:
#           Airline_Name  Food_&_Beverages  Inflight_Entertainment  \
# 0          AB Aviation                 2                       0
# 1        Adria Airways                 3                       2
# 2      Aegean Airlines                 4                       2
# 3           Aer Lingus                 3                       2
# 4             Aero VIP                 0                       0
# ..                 ...               ...                     ...
# 510  XL Airways France                 3                       2
# 511   Yakutia Airlines                 3                       0
# 512     Yangon Airways                 4                       0
# 513            Yemenia                 0                       0
# 514      Yeti Airlines                 3                       0
#
#      Seat_Comfort  Staff_Service  Value_for_Money  Review_Count  Rating
# 0               3              3                2             3       4
# ...

# %%
import matplotlib.pyplot as plt

labels = 'Food_&_Beverages', 'Inflight_Entertainment', 'Seat_Comfort', 'Staff_Service', 'Value_for_Money'
sizes = [3, 2, 3, 4, 3]
explode = (0, 0, 0, 0, 0)

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')

plt.show()

# %%
Above Stats show in percentage what Criteria Aer Lingus do Best in

# %%
import matplotlib.pyplot as plt

fig,ax=plt.subplots()

x=[1, 2, 3, 4, 5]
y=[3, 2, 3, 4, 3]

y2=[2, 2, 2, 2, 2]

ax.bar(x,y,color= "magenta")
ax.bar(x,y2,color= "green")

plt.show()

# %%
Aer Lingus Y Axis = Magenta    ///    United Airlines Y2 Axis = Green     LONGHAUL Comparison

# %%
import matplotlib.pyplot as plt

fig,ax=plt.subplots()

x=[1, 2, 3, 4, 5]
y=[3, 2, 3, 4, 3]
y2=[2, 1, 2, 3, 3]

ax.scatter(x,y,color= "magenta")
ax.plot(x,y2,color= "green", marker="*")

plt.show()

# %%
Aer Lingus Y Axis = Magenta    ///    Ryanair Y2 Axis = Green and * as Marker     Shorthaul Comparison

# %%
import matplotlib.pyplot as plt
x = ["Aer Lingus", "British Airways", "Etihad Airways", "Emirates", "Ryanair", "United Airlines", "Jet Blue", "Air Asia", "Easy Jet"]
w = [6, 5, 4, 6, 5, 3, 5, 5, 5]
c = ["red", "green", "orange", "blue", "magenta", "black", "pink"]
plt.barh(x,w,0.5,color=c)
plt.xlabel("Rating")
plt.ylabel("Airline")
plt.title("Airline Rating out of 10")
plt.show()

# %%
Seen Above is a Sample rating Score out of 10 for 7 Airlines using a Horizontal Bar Chart.

# %%
import matplotlib.pyplot as plt

fig,ax=plt.subplots()

x=[1, 2, 3, 4, 5, 6, 7]
y=[5, 0, 4, 5, 5, 2, 10]
y2=[5, 0, 4, 5, 5, 1, 10]

ax.scatter(x,y,color= "magenta")
ax.plot(x,y2,color= "green", marker="*")

plt.show()

# %%
Scatter Graph used to compare Madagasikara Airways and Rhein-Neckair

# %%
import matplotlib.pyplot as plt

fig,ax=plt.subplots()

x=[1, 2, 3, 4, 5, 6, 7]
y=[3, 2, 3, 4, 3, 789, 6]
y2=[3, 3, 3, 3, 3, 811, 5]

ax.scatter(x,y,color= "magenta")
ax.plot(x,y2,color= "green", marker="*")

plt.show()

# %%
Scatter Graph used to compare Aer Lingus and Jet Blue
