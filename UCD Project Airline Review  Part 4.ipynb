# %%
import pandas as pd

# %%
df=pd.read_csv("data.csv")

# %%
df
# Out:
#           Airline_Name  Food_&_Beverages  Inflight_Entertainment  \
# 0          AB Aviation                 2                       0
# 1        Adria Airways                 3                       2
# 2      Aegean Airlines                 4                       2
# 3           Aer Lingus                 3                       2
# 4             Aero VIP                 0                       0
# ..                 ...               ...                     ...
# 510  XL Airways France                 3                       2
# 511   Yakutia Airlines                 3                       0
# 512     Yangon Airways                 4                       0
# 513            Yemenia                 0                       0
# 514      Yeti Airlines                 3                       0
#
#      Seat_Comfort  Staff_Service  Value_for_Money  Review_Count  Rating
# 0               3              3                2             3       4
# ...

# %%
Finding a Random 15 Airlines = df.sample(15)
# Out:
#                Airline_Name  Food_&_Beverages  Inflight_Entertainment  \
# 222                Gulf Air                 3                       3
# 400        Sichuan Airlines                 3                       2
# 66             Air Zimbabwe                 4                       1
# 323              Nature Air                 0                       0
# 214        Garuda Indonesia                 4                       4
# 219  Gol Transportes Aéreos                 2                       1
# 102          Avior Airlines                 2                       1
# 507                Wizz Air                 2                       1
# 429                 Sun-Air                 5                       3
# 440           TACA Airlines                 3                       2
# 370      Red Wings Airlines                 4                       5
# 180                Egyptair                 3                       2
# ...

# %%
Sorting by Rating from Lowest to Highest = df.Rating.sort_values()
# Out:
# 445     0
# 127     1
# 87      1
# 40      1
# 427     1
#        ..
# 296    10
# 429    10
# 36     10
# 59     10
# 210    10
# Name: Rating, Length: 515, dtype: int64

# %%
Sorting by 10 Highest Overall Rating = df.Rating.sort_values(ascending=False).head(10)
# Out:
# 373    10
# 36     10
# 59     10
# 210    10
# 429    10
# 221    10
# 260    10
# 296    10
# 232     9
# 333     9
# Name: Rating, dtype: int64
